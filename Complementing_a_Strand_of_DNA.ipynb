# %%
def complement(string):
    rev_string=string[::-1] #r
    print(rev_string)
    mapping_table=str.maketrans({"A":"T","T":"A","G":"C","C":"G"})
    complemented_string=rev_string.translate(mapping_table)
    print(complemented_string)
    
complement("...")
# Out:
# ...
# ...
