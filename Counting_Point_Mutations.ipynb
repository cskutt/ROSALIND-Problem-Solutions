# %%
def check_mistakes(s1,s2):
    diff_count=0
    for i in range(0,len(s1)):
        if s1[i]!=s2[i]:
            diff_count=diff_count+1
    return diff_count


check_mistakes('...','...')
# Out:
# 430
